# %%
import pandas as pd
import matplotlib.pyplot as plt
import regex as re
import matplotlib.pyplot as plt
import seaborn as sns

# %%
TN_county_pop = pd.read_csv('../dq3-earthquakes-down-to-earth/county_pop.csv')
TN_county_pop
# Out:
#               County   2019POP
# 0    Hamilton County  367804.0
# 1    Hamilton County  367804.0
# 2      Marion County   28907.0
# 3      Morgan County   21403.0
# 4      Morgan County   21403.0
# ..               ...       ...
# 296      Dyer County   37159.0
# 297      Dyer County   37159.0
# 298    Gibson County   49133.0
# 299    Gibson County   49133.0
# 300    Gibson County   49133.0
#
# [301 rows x 2 columns]

# %%
TN_county_pop.drop_duplicates(subset='County', inplace=True)
TN_county_pop.sort_values(by='2019POP',ascending=False,inplace=True)
TN_county_pop['County'] = TN_county_pop['County'].str.replace('County','')

# %%
sns.set_palette('PuRd')
plt.figure(figsize=(20,7))
ax = sns.barplot(data=TN_county_pop,x='County',y='2019POP')
ax.set(ylabel='2019 Population',xlabel='Counties that have recorded earthquakes')
plt.xticks(rotation=90,ha='center')
ax.set_title('Population of at risk counties in 2019')
plt.show();
#i want to edit the counties so they are only on the easter and western side as well as fix the wonky centering of the xtick labels

# %%
#the above chart will go in slide number 17
